# %% [markdown]
# <a href="https://colab.research.google.com/github/sheshma0908/LMS-/blob/main/Topic_Modeling(24_2_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
reviews_datasets = pd.read_csv("/var/Reviews.csv")
reviews_datasets = reviews_datasets.head(20000)
reviews_datasets.dropna()
# Out:
#           Id   ProductId          UserId                      ProfileName  \
# 0          1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1          2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2          3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3          4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4          5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...      ...         ...             ...                              ...
# 19995  19996  B002C50X1M  A1XRXZI5KOMVDD            KAF1958 "amandaf0626"
# 19996  19997  B002C50X1M   A7G9M0IE7LABX                            Kevin
# 19997  19998  B002C50X1M  A38J5PRUDESMZF                              ray
# 19998  19999  B002C50X1M  A17TPOSAG43GSM                          Herrick
# 19999  20000  B002C50X1M  A3LWC833HQIG7J                     austin_Larry
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                         1                       1      5  1303862400
# 1                         0                       0      1  1346976000
# 2                         1                       1      4  1219017600
# 3                         3                       3      2  1307923200
# 4                         0                       0      5  1350777600
# ...                     ...                     ...    ...         ...
# 19995                     0                       0      4  1307664000
# 19996                     0                       0      5  1307059200
# 19997                     0                       0      5  1305763200
# 19998                     0                       0      3  1303171200
# 19999                     0                       0      5  1295568000
#
#                                                  Summary  \
# 0                                  Good Quality Dog Food
# 1                                      Not as Advertised
# 2                                  "Delight" says it all
# 3                                         Cough Medicine
# 4                                            Great taffy
# ...                                                  ...
# 19995                                    Crispy and tart
# 19996  Exceeded my expectations. One of the best chip...
# 19997  Awesome Goodness! (deep river kettle chips, sw...
# 19998       Pretty good, but prefer other jalapeno chips
# 19999  Excellent chips, full of flavor and just the r...
#
#                                                     Text
# 0      I have bought several of the Vitality canned d...
# 1      Product arrived labeled as Jumbo Salted Peanut...
# 2      This is a confection that has been around a fe...
# 3      If you are looking for the secret ingredient i...
# 4      Great taffy at a great price.  There was a wid...
# ...                                                  ...
# 19995  Deep River Salt & Vinegar chips are thick and ...
# 19996  I was very skeptical about buying a brand of c...
# 19997  Before you turn to other name brands out there...
# 19998  I was expecting some "serious flavor" as it wa...
# 19999  I purchased the Salt and Vinegar chips and hav...
#
# [19999 rows x 10 columns]

# %%
reviews_datasets['Text'][350]
# Out:
# 'These chocolate covered espresso beans are wonderful!  The chocolate is very dark and rich and the "bean" inside is a very delightful blend of flavors with just enough caffine to really give it a zing.'

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = count_vect.fit_transform(reviews_datasets['Text'].values.astype('U'))

# %%
CountVectorizer?

# %%
print(doc_term_matrix)
# Out:
#   (0, 1792)	1
#   (0, 13973)	1
#   (0, 2171)	1
#   (0, 4160)	1
#   (0, 5304)	1
#   (0, 9997)	1
#   (0, 5771)	1
#   (0, 10221)	1
#   (0, 9993)	2
#   (0, 7640)	1
#   (0, 7498)	1
#   (0, 12347)	1
#   (0, 9978)	1
#   (0, 7992)	1
#   (0, 11845)	1
#   (0, 1537)	2
#   (0, 7276)	1
#   (0, 5120)	1
#   (0, 910)	1
#   (1, 9993)	2
#   (1, 980)	1
#   (1, 7267)	1
#   (1, 7073)	2
#   (1, 11136)	1
#   (1, 9319)	2
#   :	:
#   (19999, 10161)	1
#   (19999, 1296)	1
#   (19999, 4741)	1
#   (19999, 13468)	1
#   (19999, 11691)	1
#   (19999, 14361)	1
#   (19999, 12890)	1
#   (19999, 11135)	1
#   (19999, 11877)	1
#   (19999, 9775)	1
#   (19999, 9628)	1
#   (19999, 13008)	1
#   (19999, 2538)	1
#   (19999, 4430)	1
#   (19999, 1435)	1
#   (19999, 2542)	2
#   (19999, 3210)	1
#   (19999, 13942)	2
#   (19999, 7720)	1
#   (19999, 13081)	1
#   (19999, 2025)	1
#   (19999, 13954)	1
#   (19999, 6223)	1
#   (19999, 6870)	1
#   (19999, 6587)	1

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=5, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
import random
for i in range(10):
  random_id = random.randint(0,len(count_vect.get_feature_names_out()))
  print(count_vect.get_feature_names_out()[random_id])
# Out:
# wagging
# oversized
# split
# stroganoff
# inches
# don
# probably
# mates
# probiotic
# uncovered

# %%
first_topic = LDA.components_[0]

# %%
top_topic_words = first_topic.argsort()[-10:]

# %%
for i in top_topic_words:
    print(count_vect.get_feature_names_out()[i])
# Out:
# water
# great
# just
# drink
# sugar
# good
# flavor
# taste
# like
# tea

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i+1}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #1:
# ['water', 'great', 'just', 'drink', 'sugar', 'good', 'flavor', 'taste', 'like', 'tea']
#
#
# Top 10 words for topic #2:
# ['br', 'chips', 'love', 'flavor', 'chocolate', 'just', 'great', 'taste', 'good', 'like']
#
#
# Top 10 words for topic #3:
# ['just', 'drink', 'orange', 'sugar', 'soda', 'water', 'like', 'juice', 'product', 'br']
#
#
# Top 10 words for topic #4:
# ['gluten', 'eat', 'free', 'product', 'like', 'dogs', 'treats', 'dog', 'br', 'food']
#
#
# Top 10 words for topic #5:
# ['cups', 'price', 'great', 'like', 'amazon', 'good', 'br', 'product', 'cup', 'coffee']

# %%
topic_values = LDA.transform(doc_term_matrix)
topic_values.shape
# Out:
# (20000, 5)

# %%
reviews_datasets['Topic'] = topic_values.argmax(axis=1)

# %%
reviews_datasets.head(3)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
#
#    Topic
# 0      3
# 1      1
# 2      1

# %%
import pandas as pd
import numpy as np
reviews_datasets = pd.read_csv("/var/Reviews.csv")
reviews_datasets = reviews_datasets.head(20000)
reviews_datasets.dropna()
# Out:
#           Id   ProductId          UserId                      ProfileName  \
# 0          1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1          2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2          3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3          4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4          5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...      ...         ...             ...                              ...
# 19995  19996  B002C50X1M  A1XRXZI5KOMVDD            KAF1958 "amandaf0626"
# 19996  19997  B002C50X1M   A7G9M0IE7LABX                            Kevin
# 19997  19998  B002C50X1M  A38J5PRUDESMZF                              ray
# 19998  19999  B002C50X1M  A17TPOSAG43GSM                          Herrick
# 19999  20000  B002C50X1M  A3LWC833HQIG7J                     austin_Larry
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                         1                       1      5  1303862400
# 1                         0                       0      1  1346976000
# 2                         1                       1      4  1219017600
# 3                         3                       3      2  1307923200
# 4                         0                       0      5  1350777600
# ...                     ...                     ...    ...         ...
# 19995                     0                       0      4  1307664000
# 19996                     0                       0      5  1307059200
# 19997                     0                       0      5  1305763200
# 19998                     0                       0      3  1303171200
# 19999                     0                       0      5  1295568000
#
#                                                  Summary  \
# 0                                  Good Quality Dog Food
# 1                                      Not as Advertised
# 2                                  "Delight" says it all
# 3                                         Cough Medicine
# 4                                            Great taffy
# ...                                                  ...
# 19995                                    Crispy and tart
# 19996  Exceeded my expectations. One of the best chip...
# 19997  Awesome Goodness! (deep river kettle chips, sw...
# 19998       Pretty good, but prefer other jalapeno chips
# 19999  Excellent chips, full of flavor and just the r...
#
#                                                     Text
# 0      I have bought several of the Vitality canned d...
# 1      Product arrived labeled as Jumbo Salted Peanut...
# 2      This is a confection that has been around a fe...
# 3      If you are looking for the secret ingredient i...
# 4      Great taffy at a great price.  There was a wid...
# ...                                                  ...
# 19995  Deep River Salt & Vinegar chips are thick and ...
# 19996  I was very skeptical about buying a brand of c...
# 19997  Before you turn to other name brands out there...
# 19998  I was expecting some "serious flavor" as it wa...
# 19999  I purchased the Salt and Vinegar chips and hav...
#
# [19999 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = tfidf_vect.fit_transform(reviews_datasets['Text'].values.astype('U'))

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components=8, random_state=42)
nmf.fit(doc_term_matrix)
# Out:
# NMF(n_components=8, random_state=42)

# %%
import random
for i in range(10):
    random_id = random.randint(0,len(tfidf_vect.get_feature_names_out()))
    print(tfidf_vect.get_feature_names_out()[random_id])
# Out:
# 70s
# paint
# marzano
# planting
# qualifications
# 94
# family
# gaggia
# edges
# dramatically

# %%
first_topic = nmf.components_[0]
top_topic_words = first_topic.argsort()[-10:]

# %%
for i in top_topic_words:
    print(tfidf_vect.get_feature_names_out()[i])
# Out:
# gluten
# just
# buy
# free
# love
# amazon
# price
# good
# product
# great

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['gluten', 'just', 'buy', 'free', 'love', 'amazon', 'price', 'good', 'product', 'great']
#
#
# Top 10 words for topic #1:
# ['bitter', 'like', 'roast', 'flavor', 'blend', 'bold', 'strong', 'cups', 'cup', 'coffee']
#
#
# Top 10 words for topic #2:
# ['water', 'product', 'organic', 'href', 'gp', 'www', 'http', 'com', 'amazon', 'br']
#
#
# Top 10 words for topic #3:
# ['love', 'bags', 'flavor', 'iced', 'earl', 'loose', 'grey', 'teas', 'green', 'tea']
#
#
# Top 10 words for topic #4:
# ['old', 'like', 'cat', 'eat', 'loves', 'treat', 'dogs', 'food', 'treats', 'dog']
#
#
# Top 10 words for topic #5:
# ['flavor', 'switch', 'sweet', 'orange', 'taste', 'soda', 'like', 'sugar', 'drink', 'juice']
#
#
# Top 10 words for topic #6:
# ['tried', 'like', 'cookies', 'best', 'dark', 'cup', 'milk', 'cocoa', 'hot', 'chocolate']
#
#
# Top 10 words for topic #7:
# ['snack', 'chip', 'vinegar', 'like', 'kettle', 'potato', 'bag', 'flavor', 'salt', 'chips']

# %%
topic_values = nmf.transform(doc_term_matrix)
reviews_datasets['Topic'] = topic_values.argmax(axis=1)
reviews_datasets.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
#
#    Topic
# 0      4
# 1      0
# 2      4
# 3      5
# 4      0
